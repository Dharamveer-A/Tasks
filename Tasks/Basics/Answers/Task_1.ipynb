# %%
# Operators 
# Given Values : 
a = 15 
b = 4
c = 9
d = 20
nums = [4, 9, 15, 25]

# %%
# 1
a + b
# Out:
# 19

# %%
# 2
d - c
# Out:
# 11

# %%
# 3
b * 2
# Out:
# 8

# %%
# 4
a % b
# Out:
# 3

# %%
# 5
c > b
# Out:
# True

# %%
# 6
(a * b) - c
# Out:
# 51

# %%
# 7
d // b
# Out:
# 5

# %%
# 8 
(a > c) and (b < d)
# Out:
# True

# %%
# 9
a in nums
# Out:
# True

# %%
# 10
c ** 2
# Out:
# 81

# %%
# 11
((a + c) // b) + (d % a)
# Out:
# 11

# %%
# 12
(a ** b) // c
# Out:
# 5625

# %%
# 13
(a < d) or (c == b)
# Out:
# True

# %%
# 14 
nums is nums
# Out:
# True

# %%
# 15
((d // b) ** 2) - (a % c)
